# %% [markdown]
# ## Demonstração rápida dos dados extraídos
#
# Visualização simples do CSV gerado a partir do Anexo I do Rol de Procedimentos da ANS.
#
# O objetivo aqui é apenas mostrar que os dados foram extraídos, tratados e estruturados corretamente.

# %%
import pandas as pd

# Carrega o CSV
df = pd.read_csv("../csv_path/table_rol.csv")

# Visualiza as 10 primeiras linhas
df.head(10)
# Out:
#                                         PROCEDIMENTO RN (alteração) VIGÊNCIA  \
# 0                            ACONSELHAMENTO GENÉTICO            NaN      NaN
# 1  ATENDIMENTO/ACOMPANHAMENTO EM HOSPITAL-DIA PSI...            NaN      NaN
# 2  ATENDIMENTO INTEGRAL AO RECÉM-NASCIDO (SALA DE...            NaN      NaN
# 3  ATENDIMENTO MÉDICO DO INTENSIVISTA EM UTI GERA...            NaN      NaN
# 4  ATENDIMENTO PEDIÁTRICO A GESTANTES (3º TRIMESTRE)            NaN      NaN
# 5   ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR            NaN      NaN
# 6                 ATIVIDADE EDUCATIVA EM SAÚDE BUCAL            NaN      NaN
# 7  ATIVIDADE EDUCATIVA EM ODONTOLOGIA PARA PAIS E...            NaN      NaN
# 8  CONDICIONAMENTO EM ODONTOLOGIA (COM DIRETRIZ D...            NaN      NaN
# 9  ESTABILIZAÇÃO DE PACIENTE POR MEIO DE CONTENÇÃ...            NaN      NaN
#
#   SEG ODONTOLOGICA SEG AMBULATORIAL  HCO  HSO  REF  PAC    DUT  \
# ...

# %%
# Verifica o nome e a quantidade de colunas
df.columns, len(df.columns)
# Out:
# (Index(['PROCEDIMENTO', 'RN (alteração)', 'VIGÊNCIA', 'SEG ODONTOLOGICA',
#         'SEG AMBULATORIAL', 'HCO', 'HSO', 'REF', 'PAC', 'DUT', 'SUBGRUPO',
#         'GRUPO', 'CAPÍTULO'],
#        dtype='object'),
#  13)

# %%
# Filtra procedimentos que são ambulatorial
df[df["SEG AMBULATORIAL"] == "AMB"].head()
# Out:
#                                          PROCEDIMENTO RN (alteração) VIGÊNCIA  \
# 0                             ACONSELHAMENTO GENÉTICO            NaN      NaN
# 4   ATENDIMENTO PEDIÁTRICO A GESTANTES (3º TRIMESTRE)            NaN      NaN
# 5    ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR            NaN      NaN
# 10  CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...            NaN      NaN
# 11  CONSULTA COM ENFERMEIRO OBSTETRA OU OBSTETRIZ ...            NaN      NaN
#
#    SEG ODONTOLOGICA SEG AMBULATORIAL  HCO  HSO  REF  PAC    DUT  \
# 0               NaN              AMB  HCO  HSO  REF  NaN    NaN
# 4               NaN              AMB  HCO  NaN  REF  NaN    NaN
# 5               NaN              AMB  NaN  NaN  REF  NaN    NaN
# 10              NaN              AMB  NaN  NaN  REF  NaN    NaN
# 11              NaN              AMB  HCO  NaN  REF  NaN  135.0
#
#                                              SUBGRUPO                 GRUPO  \
# ...

# %%
# Filtra procedimentos realizados em odontologica
df[df["SEG ODONTOLOGICA"] == "OD"].head()
# Out:
#                                          PROCEDIMENTO RN (alteração) VIGÊNCIA  \
# 6                  ATIVIDADE EDUCATIVA EM SAÚDE BUCAL            NaN      NaN
# 7   ATIVIDADE EDUCATIVA EM ODONTOLOGIA PARA PAIS E...            NaN      NaN
# 8   CONDICIONAMENTO EM ODONTOLOGIA (COM DIRETRIZ D...            NaN      NaN
# 9   ESTABILIZAÇÃO DE PACIENTE POR MEIO DE CONTENÇÃ...            NaN      NaN
# 14                              CONSULTA ODONTOLÓGICA            NaN      NaN
#
#    SEG ODONTOLOGICA SEG AMBULATORIAL  HCO  HSO  REF  PAC   DUT  \
# 6                OD              NaN  NaN  NaN  NaN  NaN   NaN
# 7                OD              NaN  NaN  NaN  NaN  NaN   NaN
# 8                OD              NaN  NaN  NaN  NaN  NaN  86.0
# 9                OD              NaN  NaN  NaN  NaN  NaN   NaN
# 14               OD              NaN  NaN  NaN  NaN  NaN   NaN
#
#                                              SUBGRUPO                 GRUPO  \
# ...
